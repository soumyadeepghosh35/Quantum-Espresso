# %% [markdown]
# XANES+PDOS for 112 rare earth doped paper (inset axes feature)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Sep 29 17:42:59 2019

@author: soumyadeep
"""

#################################################################################
#  As chain K edge absorption spectra/PDOS  (10% La doped)  @ with ch @ no ch
#################################################################################

import numpy as np
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.inset_locator import inset_axes
from mpl_toolkits.axes_grid.inset_locator import InsetPosition
from matplotlib import gridspec
from matplotlib import rc,rcParams
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from mpl_toolkits.axes_grid1.inset_locator import mark_inset



#----------------------------------
# Import data from csv files
#----------------------------------
# Absorption data As-chain K-edge  [no corehle + with corehle]
E_nch,I_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/As-chain_1s(K1).csv',
               delimiter=',', unpack=True)
E_ch,I_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/As-chain_1s(K1).csv',
               delimiter=',', unpack=True)

# pdos data As-pdos-(s+p)  [no corehle + with corehle]
E1_nch,pDos1_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/As_pdos_(s).csv',
               delimiter=',', unpack=True)
E11_nch,pDos11_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/As_pdos_(p).csv',
               delimiter=',', unpack=True)
E1_ch,pDos1_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/As_pdos_(s).csv',
               delimiter=',', unpack=True)
E11_ch,pDos11_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/As_pdos_(p).csv',
               delimiter=',', unpack=True)

# pdos data As-chain_pdos-(s+p)  [no corehle + with corehle]
E2_nch,pDos2_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/As-chain_pdos_(s).csv',
               delimiter=',', unpack=True)
E22_nch,pDos22_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/As-chain_pdos_(p).csv',
               delimiter=',', unpack=True)
E2_ch,pDos2_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/As-chain_pdos_(s).csv',
               delimiter=',', unpack=True)
E22_ch,pDos22_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/As-chain_pdos_(p).csv',
               delimiter=',', unpack=True)


# pdos data As-plain_pdos-(s+p)  [no corehle + with corehle]
E3_nch,pDos3_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/As-plane_pdos_(s).csv',
               delimiter=',', unpack=True)
E33_nch,pDos33_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/As-plane_pdos_(p).csv',
               delimiter=',', unpack=True)
E3_ch,pDos3_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/As-plane_pdos_(s).csv',
               delimiter=',', unpack=True)
E33_ch,pDos33_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/As-plane_pdos_(p).csv',
               delimiter=',', unpack=True)


# pdos data Ca_pdos-(s+p+d)  [no corehle + with corehle]
E4_nch,pDos4_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/Ca_pdos_(s).csv',
               delimiter=',', unpack=True)
E44_nch,pDos44_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/Ca_pdos_(p).csv',
               delimiter=',', unpack=True)
E444_nch,pDos444_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/Ca_pdos_(d).csv',
               delimiter=',', unpack=True)
E4_ch,pDos4_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/Ca_pdos_(s).csv',
               delimiter=',', unpack=True)
E44_ch,pDos44_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/Ca_pdos_(p).csv',
               delimiter=',', unpack=True)
E444_ch,pDos444_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/Ca_pdos_(d).csv',
               delimiter=',', unpack=True)

# pdos data Fe_pdos-(p+d)  [no corehle + with corehle]
E5_nch,pDos5_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/Fe_pdos_(p).csv',
               delimiter=',', unpack=True)
E55_nch,pDos55_nch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/La10%/Fe_pdos_(d).csv',
               delimiter=',', unpack=True)
E5_ch,pDos5_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/Fe_pdos_(p).csv',
               delimiter=',', unpack=True)
E55_ch,pDos55_ch=np.loadtxt('/media/soumyadeep/SOUMYA2/Python/XANES-112/with core hole As edges/La10% -1s ch chain/Fe_pdos_(d).csv',
               delimiter=',', unpack=True)




fig, axs = plt.subplots(7, 1,sharex=True,figsize=(4,10))
fig.subplots_adjust(hspace=0)    # Remove horizontal space between axes
legend_properties = {'weight':'bold'}

#---------------------------------------------------------
# COMMON X-AXIS CONFIGURATION
#---------------------------------------------------------
plt.xlabel('Energy (eV)',fontsize=12,fontweight='bold')
plt.xticks(fontweight='bold')
plt.rc('font', weight='bold')
plt.rc('ytick.major')
plt.rc('ytick')
#---------------------------------------------------------


#---------------------------------------------------------
# PLOT OF ABSORPTION SPECTRA 
#---------------------------------------------------------
p=axs[0].plot(E_nch,I_nch,c='firebrick',lw=2.0,label='As chain K-edge')
p=axs[0].plot(E_ch,I_ch,c='k',lw=2.0,ls='-.',label='As chain K-edge (ch)')
#axs[0].set_yticks(np.arange(-1, 35, 0.2))
box = axs[0].get_position()
axs[0].set_position([box.x0, box.y0, box.width * 1.0 , box.height * 1.8])
axs[0].set_ylim(0.2, 1.02)
axs[0].set_xlim(-5, 35)
axs[0].yaxis.set_major_locator(plt.MaxNLocator(5))
axs[0].yaxis.set_minor_locator(MultipleLocator(0.1))
axs[0].set_title('(i)',fontweight='bold',position=(0.957, 0.899),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[0].set_ylabel('Intensity (arb.unit)',fontsize=12,fontweight='bold')
leg=axs[0].legend(loc="lower right",bbox_to_anchor=(1.0,0.05),frameon=False,handlelength=0,prop=legend_properties)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())    
# for marking the absorption peaks      
axs[0].text(1.7,0.62, 'A', color='firebrick', fontsize=10, weight="bold")
axs[0].text(6.5,0.97, 'B', color='firebrick', fontsize=10, weight="bold")
axs[0].text(22.1,0.54, 'G', color='firebrick', fontsize=10, weight="bold")

axs[0].text(-0.2,0.9, 'A', color='k', fontsize=10, weight="bold")
axs[0].text(2.5,0.97, 'B', color='k', fontsize=10, weight="bold")
axs[0].text(22.1,0.68, 'G', color='k', fontsize=10, weight="bold")

axs[0].arrow(5.55,0.8, -0.7, 0, head_width=0.01, head_length=0.2, linewidth=1.0, color='g', length_includes_head=True)
axs[0].arrow(24.4,0.95, -0.7, 0, head_width=0.01, head_length=0.2, linewidth=1.0, color='g', length_includes_head=True)
#---------------------------------------------------------


'''
#---------------------------------------------------------
# PLOT OF As PARTIAL DOS 
#---------------------------------------------------------
p1=axs[1].plot(E11_nch,pDos11_nch, c='b',lw=2.0,label='As(p)-nch')
p1=axs[1].plot(E11_ch,pDos11_ch, c='r',lw=1.,ls='-.',label='As(p)-ch')
axs[1].set_ylim(0.1,6.5)
#axs[1].set_xlim(-10, 10)
axs[1].set_title('(ii)',fontweight='bold',position=(0.95, 0.817),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[1].set_ylabel('PDOS',fontsize=12,fontweight='bold')
plt.rcParams["axes.labelweight"] = "bold"
leg=axs[1].legend(loc="center right",frameon=False,handlelength=0,prop=legend_properties)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
#---------------------------------------------------------  
'''


#---------------------------------------------------------
# PLOT OF As-CHAIN PARTIAL DOS 
#---------------------------------------------------------
p2=axs[1].plot(E22_nch,pDos22_nch, c='deeppink',lw=2.0,label='As-chain(p)')
p2=axs[1].plot(E22_ch,pDos22_ch, c='g',lw=1.,ls='-.',label='As-chain(p)-ch')
#p22=axs[1].plot(E22,pDos22, c='magenta',lw=1.0,label='As-chain(s)')
axs[1].set_ylim(0.0, 3.3)
axs[1].yaxis.set_minor_locator(MultipleLocator(.75))
axs[1].set_title('(ii)',fontweight='bold',position=(0.95, 0.817),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[1].set_ylabel('PDOS',fontsize=12,fontweight='bold')
leg=axs[1].legend(loc="center right",frameon=False,handlelength=0,prop=legend_properties)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
#---------------------------------------------------------
    
    
#---------------------------------------------------------
# PLOT OF As-PLANE PARTIAL DOS 
#---------------------------------------------------------
p3=axs[2].plot(E33_nch,pDos33_nch, c='purple',lw=2.0,label='As-plane(p)')
p3=axs[2].plot(E33_ch,pDos33_ch, c='cyan',lw=1.,ls='-.',label='As-plane(p)-ch')
#p33,=axs[2].plot(E33,pDos33, c='k',lw=0.5,label='As-plane(s)')
axs[2].set_ylim(0.0, 3.7)
axs[2].yaxis.set_minor_locator(MultipleLocator(.75))
axs[2].set_title('(iii)',fontweight='bold',position=(0.94, 0.817),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[2].set_ylabel('PDOS',fontsize=12,fontweight='bold')
leg=axs[2].legend(loc="center right",frameon=False,handlelength=0,prop=legend_properties)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
#---------------------------------------------------------


#---------------------------------------------------------   
# PLOT OF Ca PARTIAL DOS [without core hole] 
#---------------------------------------------------------
p4,=axs[3].plot(E44_nch,pDos44_nch,c='g',lw=2.0,label='Ca-La(p)')
p44,=axs[3].plot(E444_nch,pDos444_nch,c='r',lw=2.0,ls='--',label='La(d)')
#p4_3,=axs[3].plot(E4_3,pDos4_3,c='navy',ls='--',lw=1.0,label='Ca(p)-ch')
#p4_4,=axs[3].plot(E4_4,pDos4_4,c='magenta',ls='--',lw=1.0,label='Ca(d)-ch')
#p444,=axs[3].plot(E444,pDos444,c='g',lw=0.8,label='Ca(s)')
#axs[2].set_yticks(np.arange(0.001, 1.0, 0.4))
axs[3].set_ylim(0.001, 26)
axs[3].yaxis.set_minor_locator(MultipleLocator(5))
#axs[3].set_yticklabels(axs[3].get_yticks(),fontweight='bold')
#axs[3].ticklabel_format(axis='y', labelweight='bold')
#axs[2].set_xlim(-10, 10)
axs[3].set_title('(iv)',fontweight='bold',position=(0.94, 0.817),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[3].set_ylabel('PDOS',fontsize=12,fontweight='bold')
leg=axs[3].legend(loc="lower right",bbox_to_anchor=(1.04,0.05),frameon=False,handlelength=0,
       prop=legend_properties,labelspacing=0.1)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
#==============================================================================       
# this is an inset axes-1 over the main axes 4
#==============================================================================
inset_axes4 = inset_axes(axs[3], 
                    width="40%", # width = 30% of parent_bbox
                    height=0.68, # height : 1 inch
                    bbox_to_anchor=(-0.20,0.02,1,1), bbox_transform=axs[3].transAxes)
#ip = InsetPosition(axs[3], [0.28, 0.4, 0.45, 0.5]) #posx, posy, width, height
#inset_axes4.set_axes_locator(ip)
boxp4,=inset_axes4.plot(E44_nch,pDos44_nch,c='g',lw=2.0)
boxp44,=inset_axes4.plot(E444_nch,pDos444_nch,c='red',ls='--',lw=2.0)
#inset_axes4.xticks(list(range(5,24+1)),[str(i) for i in range(1,24+1)])
inset_axes4.set_xticks(np.arange(-5, 35, 10))
#inset_axes.get_shared_x_axes().join(inset_axes, axs[5])
inset_axes4.set_xlim(10.0,26.1)
inset_axes4.set_ylim(1, 3)
plt.xticks([])
#plt.yticks([])
#inset_axes4.xaxis.tick_top()
inset_axes4.yaxis.tick_right()
inset_axes4.tick_params(axis='y', which='major', pad=1, labelsize = 6.0)
mark_inset(axs[3], inset_axes4, loc1=3, loc2=4, fc="none", ec="0.5",lw=0.5)
#==============================================================================       
# this is an inset axes-2 over the main axes 4
#==============================================================================
inset_axes4_1 = inset_axes(axs[3], 
                    width="20%", # width = 30% of parent_bbox
                    height=0.6, # height : 1 inch)
                    )
ip = InsetPosition(axs[3], [0.05, 0.4, 0.15, 0.55]) #posx, posy, width, height
inset_axes4_1.set_axes_locator(ip)
boxp4,=inset_axes4_1.plot(E44_nch,pDos44_nch,c='g',lw=2.0)
boxp44,=inset_axes4_1.plot(E444_nch,pDos444_nch,c='red',ls='--',lw=2.0)
#inset_axes4.xticks(list(range(5,24+1)),[str(i) for i in range(1,24+1)])
inset_axes4_1.set_xticks(np.arange(-5, 35, 10))
inset_axes4_1.yaxis.set_major_locator(plt.MaxNLocator(3))
inset_axes4_1.yaxis.set_major_formatter(FormatStrFormatter('%1d'))
#inset_axes.get_shared_x_axes().join(inset_axes, axs[5])
inset_axes4_1.set_xlim(-3,3)
inset_axes4_1.set_ylim(0,3.2)
plt.xticks([])
#plt.yticks([])
#inset_axes4_1.xaxis.tick_top()
#inset_axes4_1.yaxis.tick_right()
inset_axes4_1.tick_params(axis='y', which='major', pad=1, labelsize = 6.0)
mark_inset(axs[3], inset_axes4_1, loc1=3, loc2=4, fc="none", ec="0.5",lw=0.5)
#---------------------------------------------------------


#---------------------------------------------------------
# PLOT OF Ca PARTIAL DOS [with core hole]
#---------------------------------------------------------
p4,=axs[4].plot(E44_ch,pDos44_ch,c='g',lw=2.0,label='Ca-La(p)-ch')
p44,=axs[4].plot(E444_ch,pDos444_ch,c='r',lw=2.0,ls='--',label='La(d)-ch')
axs[4].set_ylim(0.001, 26)
axs[4].yaxis.set_minor_locator(MultipleLocator(5))
axs[4].set_title('(v)',fontweight='bold',position=(0.95, 0.817),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[4].set_ylabel('PDOS',fontsize=12,fontweight='bold')
leg=axs[4].legend(loc="lower right",bbox_to_anchor=(0.75,0.11),frameon=False,handlelength=0,
       prop=legend_properties,labelspacing=0.1)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
#==============================================================================       
# this is an inset axes-1 over the main axes 5
#==============================================================================
inset_axes5 = inset_axes(axs[4], 
                    width="40%", # width = 30% of parent_bbox
                    height=0.68, # height : 1 inch
                    bbox_to_anchor=(-0.20,0.02,1,1), bbox_transform=axs[4].transAxes)
#ip = InsetPosition(axs[3], [0.28, 0.4, 0.45, 0.5]) #posx, posy, width, height
#inset_axes5.set_axes_locator(ip)
boxp4,=inset_axes5.plot(E44_ch,pDos44_ch,c='g',lw=2.0)
boxp44,=inset_axes5.plot(E444_ch,pDos444_ch,c='red',ls='--',lw=2.0)
#inset_axes5.xticks(list(range(5,24+1)),[str(i) for i in range(1,24+1)])
inset_axes5.set_xticks(np.arange(-5, 35, 10))
#inset_axes.get_shared_x_axes().join(inset_axes, axs[5])
inset_axes5.set_xlim(10.0,26.1)
inset_axes5.set_ylim(1, 3)
plt.xticks([])
#plt.yticks([])
#inset_axes5.xaxis.tick_top()
inset_axes5.yaxis.tick_right()
inset_axes5.tick_params(axis='y', which='major', pad=1, labelsize = 6.0)
mark_inset(axs[4], inset_axes5, loc1=3, loc2=4, fc="none", ec="0.5",lw=0.5)
#==============================================================================       
# this is an inset axes-2 over the main axes 5
#==============================================================================
inset_axes5_1 = inset_axes(axs[4], 
                    width="20%", # width = 30% of parent_bbox
                    height=0.6, # height : 1 inch)
                    )
ip = InsetPosition(axs[4], [0.05, 0.4, 0.15, 0.55]) #posx, posy, width, height
inset_axes5_1.set_axes_locator(ip)
boxp4,=inset_axes5_1.plot(E44_ch,pDos44_ch,c='g',lw=2.0)
boxp44,=inset_axes5_1.plot(E444_ch,pDos444_ch,c='red',ls='--',lw=2.0)
#inset_axes5.xticks(list(range(5,24+1)),[str(i) for i in range(1,24+1)])
inset_axes5_1.set_xticks(np.arange(-5, 35, 10))
inset_axes5_1.yaxis.set_major_locator(plt.MaxNLocator(3))
inset_axes5_1.yaxis.set_major_formatter(FormatStrFormatter('%1d'))
#inset_axes.get_shared_x_axes().join(inset_axes, axs[5])
inset_axes5_1.set_xlim(-3,3)
inset_axes5_1.set_ylim(0,3.2)
plt.xticks([])
#plt.yticks([])
#inset_axes5_1.xaxis.tick_top()
#inset_axes5_1.yaxis.tick_right()
inset_axes5_1.tick_params(axis='y', which='major', pad=1, labelsize = 6.0)
mark_inset(axs[4], inset_axes5_1, loc1=3, loc2=4, fc="none", ec="0.5",lw=0.5)
#---------------------------------------------------------


    

#---------------------------------------------------------
# PLOT OF Fe PARTIAL DOS [no core hole]
#---------------------------------------------------------
p5,=axs[5].plot(E5_nch,pDos5_nch,c='magenta',lw=2.0,label='Fe(p)')
p55,=axs[5].plot(E55_nch,pDos55_nch,c='navy',lw=2.0,ls='--',label='Fe(d)')
#p5_3,=axs[5].plot(E5_3,pDos5_3,c='navy',ls='--',lw=1.0,label='Fe(p)-ch')
#p5_4,=axs[5].plot(E5_4,pDos5_4,c='magenta',ls='--',lw=1.0,label='Fe(d)-ch')
#axs[3].set_yticks(np.arange(-0.9, 1.0, 0.4))
axs[5].set_ylim(0, 14.5)
axs[5].yaxis.set_minor_locator(MultipleLocator(2.5))
#axs[3].set_xlim(-10, 10)
axs[5].set_title('(vi)',fontweight='bold',position=(0.94, 0.817),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[5].set_ylabel('PDOS',fontsize=12,fontweight='bold')
leg=axs[5].legend(loc="lower right",bbox_to_anchor=(1.02,0),frameon=False,handlelength=0,prop=legend_properties)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
#==============================================================================       
# this is an inset axes-1 over the main axes 6
#============================================================================== 
inset_axes6 = inset_axes(axs[5], 
                    width="55%", # width = 30% of parent_bbox
                    height=0.7, # height : 1 inch
                    loc=9)
boxp5,=inset_axes6.plot(E5_nch,pDos5_nch,c='magenta',lw=2.0)
boxp55,=inset_axes6.plot(E55_nch,pDos55_nch,c='navy',lw=2.0,ls='--')
#inset_axes6.set_xticks(np.arange(-5, 35, 5))
#inset_axes.get_shared_x_axes().join(inset_axes, axs[5])
inset_axes6.set_xlim(4,26)
inset_axes6.set_ylim(0, 3)
plt.xticks([])
#plt.yticks()
#inset_axes6.yaxis.set_major_locator(plt.MaxNLocator(4))
inset_axes6.yaxis.tick_right()
inset_axes6.tick_params(axis='y', which='major', pad=1, labelsize = 6.0)
mark_inset(axs[5], inset_axes6, loc1=3, loc2=4, fc="none", ec="0.5",lw=0.5)
#---------------------------------------------------------


#---------------------------------------------------------
# PLOT OF Fe PARTIAL DOS [with core hole]
#---------------------------------------------------------
p5,=axs[6].plot(E5_ch,pDos5_ch,c='magenta',lw=2.0,label='Fe(p)-ch')
p55,=axs[6].plot(E55_ch,pDos55_ch,c='navy',lw=2.0,ls='--',label='Fe(d)-ch')
#p5_3,=axs[6].plot(E5_3,pDos5_3,c='navy',ls='--',lw=1.0,label='Fe(p)-ch')
#p5_4,=axs[6].plot(E5_4,pDos5_4,c='magenta',ls='--',lw=1.0,label='Fe(d)-ch')
#axs[3].set_yticks(np.arange(-0.9, 1.0, 0.4))
axs[6].set_ylim(0, 14.5)
axs[6].yaxis.set_minor_locator(MultipleLocator(2.5))
#axs[6].set_yticklabels(axs[6].get_yticks(),fontweight='bold')
axs[6].set_title('(vii)',fontweight='bold',position=(0.93, 0.817),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[6].set_ylabel('PDOS',fontsize=12,fontweight='bold')
leg=axs[6].legend(loc="lower right",bbox_to_anchor=(1.04,0),frameon=False,handlelength=0,prop=legend_properties)
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
#==============================================================================       
# this is an inset axes-1 over the main axes 7
#==============================================================================  
inset_axes7 = inset_axes(axs[6], 
                    width="55%", # width = 30% of parent_bbox
                    height=0.7, # height : 1 inch
                    loc=9)
boxp5,=inset_axes7.plot(E5_ch,pDos5_ch,c='magenta',lw=2.0)
boxp55,=inset_axes7.plot(E55_ch,pDos55_ch,c='navy',lw=2.0,ls='--')
#inset_axes7.set_xticks(np.arange(-5, 35, 5))
#inset_axes.get_shared_x_axes().join(inset_axes, axs[6])
inset_axes7.set_xlim(4,26)
inset_axes7.set_ylim(0, 3)
plt.xticks([])
#plt.yticks()
#inset_axes7.yaxis.set_major_locator(plt.MaxNLocator(4))
inset_axes7.yaxis.tick_right()
inset_axes7.tick_params(axis='y', which='major', pad=1, labelsize = 6.0)
mark_inset(axs[6], inset_axes7, loc1=3, loc2=4, fc="none", ec="0.5",lw=0.5)
#---------------------------------------------------------



#---------------------------------------------------------
# TO PUT HORIZONTAL LINE ACCROSS ALL SUBPLOTS
#---------------------------------------------------------
for i in range(7):
    axs[i].axvline(x=1.50,color='firebrick', ls='--',lw=1.0)
    axs[i].axvline(x=5.60,color='firebrick', ls='--',lw=0.5)
    axs[i].axvline(x=24.5,color='firebrick', ls='--',lw=0.5)
    
    axs[i].axvline(x=1.5,color='k', ls='--',lw=0.5)
    axs[i].axvline(x=4.74,color='k', ls='--',lw=0.5)
    axs[i].axvline(x=23.64,color='k', ls='--',lw=0.5)
# ----> FOR BOXPLOT-4
inset_axes4.axvline(x=24.5,color='firebrick', ls='--',lw=0.5)
inset_axes4_1.axvline(x=1.50,color='firebrick', ls='--',lw=0.5) 
# ----> FOR BOXPLOT-5
inset_axes5.axvline(x=23.64,color='k', ls='--',lw=0.5)
inset_axes5_1.axvline(x=1.5,color='k', ls='--',lw=0.5) 
# ----> FOR BOXPLOT-6  
inset_axes6.axvline(x=5.60,color='firebrick', ls='--',lw=0.5)
inset_axes6.axvline(x=24.5,color='firebrick', ls='--',lw=0.5)
# ----> FOR BOXPLOT-7  
inset_axes7.axvline(x=4.74,color='k', ls='--',lw=0.5)
inset_axes7.axvline(x=23.64,color='k', ls='--',lw=0.5)  
#---------------------------------------------------------



#---------------------------------------------------------
# TO SET TICS PARAMETERS OF SUBPLOTS 
#---------------------------------------------------------
for i in range(7):
    if i==0:
        axs[i].tick_params(axis='x',length=4.0, direction='in', bottom=False, top=True,labelsize = 8.0)
        axs[i].tick_params(axis='y',length=4.0, labelsize = 8.0)
    else:
        axs[i].tick_params(axis='x', which='both', length=4.0, direction='inout', bottom=True, top=True, left=True, right=False, labelsize = 8.0)
        axs[i].tick_params(axis='y',length=4.0, labelsize = 8.0)

# ----> MAJOR/MINOR TICK SETTING
for i in range(1,7):
    axs[i].yaxis.set_major_locator(plt.MaxNLocator(3))
    axs[i].xaxis.set_minor_locator(MultipleLocator(2.5))
    #axs[i].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
#---------------------------------------------------------


#---------------------------------------------------------
# FOR TITLE OF SUBPLOTS
#---------------------------------------------------------
plt.suptitle('10% La doped',y=0.985,weight='bold',size=12)


#---------------------------------------------------------
# TO SHOW PLOTTED PLOT IN IPYTHON CONSOLE  
#---------------------------------------------------------
plt.show()



#---------------------------------------------------------
# FOR SAVING PLOTTED FIGURE 
#---------------------------------------------------------
#plt.tight_layout()
#plt.subplots_adjust(wspace=0, hspace=0)
fig.set_size_inches(4,12)
plt.savefig('/media/soumyadeep/SOUMYA2/Python/test_fig.pdf',bbox_inches='tight', dpi=1500)
#plt.savefig("/media/soumyadeep/SOUMYA2/Python/XANES-112/Final plots and programs/plots/10La_As-chainK-DOS-nch+ch.pdf",bbox_inches='tight', dpi=4500)
#plt.savefig("/media/soumyadeep/SOUMYA2/Python/XANES-112/Final plots and programs/plots/10La_As-chainK-DOS-nch+ch.eps",bbox_inches='tight', dpi=4500)
#plt.savefig("/media/soumyadeep/SOUMYA2/Python/XANES-112/Final plots and programs/plots/10La_As-chainK-DOS-nch+ch.jpeg",bbox_inches='tight', dpi=1500)
#---------------------------------------------------------

# %% [markdown]
# XANES+PDOS for hybrid paper

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Nov 12 16:21:58 2020

@author: soumyadeep
"""



###################################################
#    ELNES vs PDOS| KFe2As2
###################################################



import numpy as np
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.inset_locator import inset_axes
from mpl_toolkits.axes_grid.inset_locator import InsetPosition
from matplotlib import gridspec
from matplotlib import rc,rcParams
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import matplotlib.patches as patches

NAME='Ca22'
data_dir='/media/soumyadeep/SOUMYA2/Python/XANES-hybrid/Ca22_PDOS'

# XANES plotting part Absorption data for Fe K edge
E,I=np.loadtxt(data_dir+'/222SC-nch/XANES-FeK-nch.csv',delimiter=',', skiprows=0 + 1, unpack=True)
E_ch,I_ch=np.loadtxt(data_dir+'/222SC-Fe1s/XANES-FeK-1sch.csv',delimiter=',', skiprows=0 + 1, unpack=True)


# pdos data K_pdos_(p)
E1,pDos1=np.loadtxt(data_dir+'/222SC-nch/Ca_pdos_(d).csv',delimiter=',', unpack=True)
E1_ch,pDos1_ch=np.loadtxt(data_dir+'/222SC-Fe1s/Ca_pdos_(d).csv',delimiter=',', unpack=True)

# pdos data As_pdos_(p)
E2,pDos2=np.loadtxt(data_dir+'/222SC-nch/As_pdos_(p).csv',delimiter=',', unpack=True)
E2_ch,pDos2_ch=np.loadtxt(data_dir+'/222SC-Fe1s/As_pdos_(p).csv',delimiter=',', unpack=True)

# pdos data Fe (p+d)
E3,pDos3=np.loadtxt(data_dir+'/222SC-nch/Fe_pdos_(p).csv',delimiter=',', unpack=True)
E33,pDos33=np.loadtxt(data_dir+'/222SC-nch/Fe_pdos_(d).csv',delimiter=',', unpack=True)
E3_ch,pDos3_ch=np.loadtxt(data_dir+'/222SC-Fe1s/Fe_pdos_(p).csv',delimiter=',', unpack=True)
E33_ch,pDos33_ch=np.loadtxt(data_dir+'/222SC-Fe1s/Fe_pdos_(d).csv',delimiter=',', unpack=True)



fig, axs = plt.subplots(7, 1,sharex=True,figsize=(4,14))
fig.subplots_adjust(hspace=0)    # Remove horizontal space between axes
legend_properties = {'weight':'bold'}
#
# COMMON X-AXIS CONFIGURATION ---------------------------------------------------------
plt.xlabel('Energy (eV)',fontsize=10,fontweight='bold')
plt.xticks(fontweight='bold')
#plt.tick_params(labeltop=True)
plt.rc('font', weight='bold')
plt.rc('ytick.major')
plt.rc('ytick')
# END OF THIS SECTION ------------------------------------------------------------------


# PLOT OF ABSORPTION SPECTRA ------------------------------------------------------------
p=axs[0].plot(E,I,c='r',lw=1.5,label='without core-hole')
p=axs[0].plot(E_ch,I_ch,c='navy',lw=1.5,ls='-.',label='with core-hole')
#axs[0].set_yticks(np.arange(-1, 35, 0.2))
box = axs[0].get_position()
axs[0].set_position([box.x0, box.y0, box.width * 1.0 , box.height * 1.8])
axs[0].set_ylim(0.1, 1.05)
axs[0].set_xlim(-2.5, 30)
axs[0].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axs[0].set_title('(i)',fontweight='bold',position=(0.04, 0.90),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[0].set_ylabel('Norm. Intensity (arb.unit)',fontsize=10,fontweight='bold')
leg=axs[0].legend(loc="lower right",bbox_to_anchor=(0.95,0.1),frameon=True,framealpha=1.0,handlelength=2,
       prop=legend_properties,facecolor='bisque',edgecolor='white')
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())    


# to name absorption peaks
axs[0].text(0,0.35, 'A',color='r', fontsize=10)
axs[0].text(3.2,0.5, 'B',color='r', fontsize=10)
axs[0].text(8.0,0.87, 'C',color='r', fontsize=10)
axs[0].text(14.1,1.0, 'D',color='r', fontsize=10)
axs[0].text(27.65,1.01, 'E',color='r', fontsize=10)

axs[0].text(1.3,0.26, r'$\rm A^{\prime} $',color='navy', fontsize=10)
axs[0].text(4.42,0.41, r'$\rm B^{\prime} $', color='navy', fontsize=10)
axs[0].text(9.5,0.79, r'$\rm C^{\prime} $',color='navy', fontsize=10)
axs[0].text(14.0,0.88, r'$\rm D^{\prime} $',color='navy', fontsize=10)
axs[0].text(27.1,0.93, r'$\rm E^{\prime} $',color='navy', fontsize=10)

# END OF PLOT ----------------------------------------------------------------------------------

# PLOT OF K PARTIAL DOS (without core-hole) -------------------------------------------------------------------
p=axs[1].plot(E1,pDos1,c='orange',lw=0.5,label='Ca(p)')
axs[1].set_ylim(0, 8.5)
axs[1].yaxis.set_major_locator(plt.MaxNLocator(4))
axs[1].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axs[1].set_title('(ii)',fontweight='bold',position=(0.95, 0.82),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[1].set_ylabel('PDOS',fontsize=10,fontweight='bold')
leg=axs[1].legend(loc="upper right",frameon=True,framealpha=1.0,handlelength=2,
       prop=legend_properties,bbox_to_anchor=(1.0,0.7),facecolor='bisque',edgecolor='white')
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
# for space filling
axs[1].fill_between(E1,pDos1, 0, facecolor='orange', color='orange', alpha=0.4)  


# PLOT OF K PARTIAL DOS (with core-hole) -------------------------------------------------------------------
p=axs[2].plot(E1_ch,pDos1_ch,c='g',lw=0.5,label='Ca(p)-wch')
axs[2].set_ylim(0,68)
axs[2].yaxis.set_major_locator(plt.MaxNLocator(4))
axs[2].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axs[2].set_title('(iii)',fontweight='bold',position=(0.94, 0.82),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[2].set_ylabel('PDOS',fontsize=10,fontweight='bold')
leg=axs[2].legend(loc="upper right",frameon=True,framealpha=1.0,handlelength=2,
       prop=legend_properties,bbox_to_anchor=(1.0,0.7),facecolor='bisque',edgecolor='white')
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
# for space filling
axs[2].fill_between(E1_ch,pDos1_ch, 0, facecolor='g', color='g', alpha=0.4)  
    

# PLOT OF K PARTIAL DOS (without core-hole) -------------------------------------------------------------------
p=axs[3].plot(E2,pDos2,c='magenta',lw=0.5,label='As(p)')
axs[3].set_ylim(0, 1.7)
axs[3].yaxis.set_major_locator(plt.MaxNLocator(4))
axs[3].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axs[3].set_title('(iv)',fontweight='bold',position=(0.94, 0.82),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[3].set_ylabel('PDOS',fontsize=10,fontweight='bold')
leg=axs[3].legend(loc="upper right",frameon=True,framealpha=1.0,handlelength=2,
       prop=legend_properties,bbox_to_anchor=(1.0,0.7),facecolor='bisque',edgecolor='white')
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
# for space filling
axs[3].fill_between(E2,pDos2, 0, facecolor='magenta', color='magenta', alpha=0.4)  


# PLOT OF As PARTIAL DOS (with core-hole) -------------------------------------------------------------------
p=axs[4].plot(E2_ch,pDos2_ch,c='c',lw=0.5,label='As(p)-wch')
axs[4].set_ylim(0, 13.5)
axs[4].yaxis.set_major_locator(plt.MaxNLocator(4))
axs[4].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axs[4].set_title('(v)',fontweight='bold',position=(0.95, 0.82),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[4].set_ylabel('PDOS',fontsize=10,fontweight='bold')
leg=axs[4].legend(loc="upper right",frameon=True,framealpha=1.0,handlelength=2,
       prop=legend_properties,bbox_to_anchor=(1.0,0.7),facecolor='bisque',edgecolor='white')
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
# for space filling
axs[4].fill_between(E2_ch,pDos2_ch, 0, facecolor='c', color='c', alpha=0.4)  
    
    
# PLOT OF Fe PARTIAL DOS (without core-hole) -------------------------------------------------------------------
p=axs[5].plot(E3,pDos3,c='purple',lw=0.5,label='Fe(p)')
p=axs[5].plot(E33,pDos33,c='limegreen',lw=0.5,ls="-.",label='Fe(d)')
axs[5].set_ylim(0, 5)
axs[5].yaxis.set_major_locator(plt.MaxNLocator(4))
axs[5].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axs[5].set_title('(vi)',fontweight='bold',position=(0.94, 0.82),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[5].set_ylabel('PDOS',fontsize=10,fontweight='bold')
leg=axs[5].legend(loc="upper right",frameon=True,framealpha=1.0,handlelength=2,
       prop=legend_properties,bbox_to_anchor=(1.0,0.7),facecolor='bisque',edgecolor='white')
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
# for space filling
axs[5].fill_between(E3,pDos3, 0, facecolor='purple', color='purple', alpha=0.4)   
axs[5].fill_between(E33,pDos33, 0, facecolor='limegreen', color='limegreen', alpha=0.5) 

# PLOT OF Fe PARTIAL DOS (with core-hole) -------------------------------------------------------------------
p=axs[6].plot(E3_ch,pDos3_ch,c='purple',lw=0.5,label='Fe(p)-wch')
p=axs[6].plot(E33_ch,pDos33_ch,c='limegreen',ls="-.",lw=0.5,label='Fe(p)-wch')
axs[6].set_ylim(0, 50)
axs[6].yaxis.set_major_locator(plt.MaxNLocator(4))
axs[6].yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
axs[6].set_title('(vii)',fontweight='bold',position=(0.93, 0.82),bbox={'facecolor':'white', 'alpha':1.0, 'pad':1.5})
axs[6].set_ylabel('PDOS',fontsize=10,fontweight='bold')
leg=axs[6].legend(loc="upper right",frameon=True,framealpha=1.0,handlelength=2,
       prop=legend_properties,bbox_to_anchor=(1.0,0.7),facecolor='bisque',edgecolor='white')
# change the font colors to match the line colors:
for line,text in zip(leg.get_lines(), leg.get_texts()):
    text.set_color(line.get_color())
# for space filling
axs[6].fill_between(E3_ch,pDos3_ch, 0, facecolor='purple', color='purple', alpha=0.4)   
axs[6].fill_between(E33_ch,pDos33_ch, 0, facecolor='limegreen', color='limegreen', alpha=0.5) 

# TO PUT HORIZONTAL LINE ACCROSS ALL SUBPLOTS -----------------------------------------------------
for i in range(7):
    axs[i].axvline(x=1.37,color='r', ls='--',lw=0.5)
    axs[i].axvline(x=4.42,color='r', ls='--',lw=0.5)
    axs[i].axvline(x=9.45,color='r', ls='--',lw=0.5)
    axs[i].axvline(x=14.0,color='r', ls='--',lw=0.5)
    axs[i].axvline(x=27.58,color='r', ls='--',lw=0.5)
    
    axs[i].axvline(x=1.27,color='navy', ls='-.',lw=0.5)
    axs[i].axvline(x=4.42,color='navy', ls='-.',lw=0.5)
    axs[i].axvline(x=9.34,color='navy', ls='-.',lw=0.5)
    axs[i].axvline(x=13.85,color='navy', ls='-.',lw=0.5)
    axs[i].axvline(x=27.0,color='navy', ls='-.',lw=0.5)    
# FOR BOXPLOT-4
#inset_axes2.axvline(x=8.54,color='k', ls='-.',lw=0.5)
#inset_axes2.axvline(x=15.74,color='k', ls='-.',lw=0.5)
# FOR BOXPLOT-5  
#inset_axes3.axvline(x=8.39,color='k', ls='-.',lw=0.5)    
#inset_axes3.axvline(x=12.92,color='k', ls='-.',lw=0.5)  
#inset_axes3.axvline(x=18.91,color='k', ls='-.',lw=0.5)  

# END OF HORIZONTAL LINE SECTION --------------------------------------------------------------


 
# TO SET TICS PARAMETERS OF SUBPLOTS --------------------------------------------------------
for i in range(7):
    if i==0:
        axs[i].tick_params(axis='x', length=6.0, direction='in', bottom=False, top=True,labelsize = 8)
        axs[i].tick_params(axis='y',length=6.0, labelsize = 10.0)
    else:
        axs[i].tick_params(axis='x', which='both', length=6.0, direction='inout', bottom=True, top=True, left=True, right=False, labelsize = 10.0)
        axs[i].tick_params(axis='y',length=6.0, labelsize = 10.0)
# For minor axis
for i in range(7):
    axs[i].xaxis.set_minor_locator(MultipleLocator(2.5))
    axs[0].yaxis.set_minor_locator(MultipleLocator(0.1))
    axs[1].yaxis.set_minor_locator(MultipleLocator(1.25))
    axs[2].yaxis.set_minor_locator(MultipleLocator(10))
    axs[3].yaxis.set_minor_locator(MultipleLocator(0.25))
    axs[4].yaxis.set_minor_locator(MultipleLocator(2.0))
    axs[5].yaxis.set_minor_locator(MultipleLocator(0.75))
    axs[6].yaxis.set_minor_locator(MultipleLocator(7.5))
    axs[i].tick_params(axis='x', which='minor', length=4, direction='inout')
    axs[i].tick_params(axis='y', which='minor', length=4, direction='out')
# END OF SECTION -------------------------------------------------------------------------


# TO SHOW PLOTTED PLOT IN IPYTHON CONSOLE  ----------------------------------------------   
plt.show()



plt.suptitle(r'$\rm CaFe_2As_2$ Fe K-edge XANES',y=0.985,weight='bold',size=12)
#
# FOR SAVING PLOTTED FIGURE -------------------------------------------------------------
#plt.tight_layout(pad=0)
#plt.subplots_adjust(wspace=0, hspace=0)
fig.set_size_inches(4,12)
SAVE_DIR='/media/soumyadeep/SOUMYA2/Python/XANES-hybrid/plots'
plt.savefig('/media/soumyadeep/SOUMYA2/Python/test_fig.pdf',bbox_inches='tight', dpi=2500)
#plt.savefig(SAVE_DIR+"/Ca22_FeK+PDOS.pdf",bbox_inches='tight', dpi=4500)
#plt.savefig(SAVE_DIR+"/Ca22_FeK+PDOS.eps",bbox_inches='tight', dpi=4500)
#plt.savefig(SAVE_DIR+"/Ca22_FeK+PDOS.png",bbox_inches='tight', dpi=1500)
#plt.savefig(SAVE_DIR+"/Ca22_FeK+PDOS.tiff",bbox_inches='tight', dpi=500)
# END OF SAVING SECTION -------------------------------------------------------------------
